# %%
# %% [markdown]
# # Check Bonds in a TPR File
# This notebook uses MDAnalysis to inspect bonds in a GROMACS TPR file.

# %%

# %%
from MDAnalysis.lib.formats import NDXReader

ndx = NDXReader("index.ndx")

# group names
names = list(ndx.groups.keys())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 from MDAnalysis.lib.formats import NDXReader
#       3 ndx = NDXReader("index.ndx")
#       5 # group names
#
# ImportError: cannot import name 'NDXReader' from 'MDAnalysis.lib.formats' (/Users/lucasroeleveld/.venvs/brewpython_main/lib/python3.13/site-packages/MDAnalysis/lib/formats/__init__.py)

# %%
from molsim.parsers import NdxParser
import itertools as it
ndx = NdxParser("index.ndx")

# group names
for i, line in zip(range(100), ndx.lines(0)):
    print(i, line)

print(ndx.filenames)
# Out:
# 0 [ POPC_phosphate ]
#
# 1 332 333 334 335 336 466 467 468 469 470 600 601
#
# 2 602 603 604 734 735 736 737 738 868 869 870 871
#
# 3 872 1002 1003 1004 1005 1006 1136 1137 1138 1139 1140 1270
#
# 4 1271 1272 1273 1274 1404 1405 1406 1407 1408 1538 1539 1540
#
# 5 1541 1542 1672 1673 1674 1675 1676 1806 1807 1808 1809 1810
#
# 6 1940 1941 1942 1943 1944 2074 2075 2076 2077 2078 2208 2209
#
# 7 2210 2211 2212 2342 2343 2344 2345 2346 2476 2477 2478 2479
#
# 8 2480 2610 2611 2612 2613 2614 2744 2745 2746 2747 2748 2878
#
# 9 2879 2880 2881 2882 3012 3013 3014 3015 3016 3146 3147 3148
#
# 10 3149 3150 3280 3281 3282 3283 3284 3414 3415 3416 3417 3418
#
# 11 3548 3549 3550 3551 3552 3682 3683 3684 3685 3686 3816 3817
#
# 12 3818 3819 3820 3950 3951 3952 3953 3954 4084 4085 4086 4087
#
# 13 4088 4218 4219 4220 4221 4222 4352 4353 4354 4355 4356 4486
#
# 14 4487 4488 4489 4490 4620 4621 4622 4623 4624 4754 4755 4756
#
# 15 4757 4758 4888 4889 4890 4891 4892 5022 5023 5024 5025 5026
#
# ...
